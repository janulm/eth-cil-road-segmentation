# %%
from utils.image_loading import *

# %%
training_rbgs = load_training_images()
groundtruth_rgbs = load_groundtuth_images()
test_regbs = load_test_images()

# %%
print(training_rbgs)
# Out:
# [array([[[ 56,  72,  96],
#         [ 60,  68, 100],
#         [ 49,  65,  98],
#         ...,
#         [203, 203, 211],
#         [203, 203, 211],
#         [203, 203, 211]],
#
#        [[ 57,  73, 106],
#         [ 42,  57,  83],
#         [ 49,  65,  98],
#         ...,
#         [203, 203, 211],
#         [199, 203, 199],
#         [203, 203, 211]],
#
#        [[ 58,  74,  90],
#         [ 26,  42,  73],
#         [ 41,  52,  82],
#         ...,
#         [203, 203, 211],
#         [195, 199, 203],
#         [199, 203, 199]],
#
#        ...,
#
#        [[ 52,  68,  68],
#         [116, 135, 135],
#         [179, 183, 195],
#         ...,
#         [ 50,  65,  91],
#         [ 57,  73, 106],
#         [ 57,  73, 106]],
#
#        [[ 87,  88,  87],
#         [124, 131, 123],
#         [173, 173, 178],
#         ...,
#         [ 36,  56,  80],
#         [ 50,  65,  91],
#         [ 56,  72,  96]],
#
#        [[ 68,  74,  74],
#         [ 68,  74,  74],
#         [104, 112, 104],
# ...
